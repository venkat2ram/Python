# %% [markdown]
# <a href="https://colab.research.google.com/github/venkat2ram/Python/blob/master/Asgn2_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	Plot a line graph for the following values x = [1, 2, 3] and y = [2, 4, 1] and print the respective x, y labels and title named as “line graph” and take a screen shot of the graph.

# %%
from matplotlib import pyplot as plt
x = [1, 2, 3] 
y = [2, 4, 1]
plt.plot(x,y)
plt.title('line graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %% [markdown]
# 2.	Create a multi-line graph for the following values x1 = [1, 2, 3 ] and y1 = [2, 4, 1] and plot the graph and mark label as “line 1 “ with green color and another set of values x2 = [1, 2, 3] and y2 = [4, 1, 3] and plot the graph and mark label as “line 2” with red color and print the respective x, y labels and title named as “two lines on the graph” use grid in the graph and grid color is black and take a screen shot of the graph.

# %%
x1 = [1, 2, 3 ] 
y1 = [2, 4, 1] 
x2 = [1, 2, 3] 
y2 = [4, 1, 3]
plt.plot(x1,y1,'g',label='line1')
plt.plot(x2,y2,'r',label='line2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('two lines on the graph')
plt.legend()
plt.show()

# %% [markdown]
# 3.	Create a bar graph for the movies data number of movies released in the year as x = [2016, 2017, 2018] and year as y = [1252, 1632, 1692] with colors red and blue and print the respective x, y labels and title named as “movies bar graph”.

# %%
x = [2016, 2017, 2018]
y = [1252, 1632, 1692] 
plt.bar(x,y, width=0.8,tick_label=x, color=['red','blue'])
plt.title('movies bar graph')
plt.xlabel('Year')
plt.ylabel('Number of movies')
plt.show()

# %% [markdown]
# 4. Plot a Pie graph with following values days = [1, 2, 3, 4, 5] and bike names as activities for example Enfield = [50, 40, 70, 80, 20]  Honda = [80,20,20,50,60] Yahama = [70,20,60,40,60]  KTM = [80,20,20,50,60] and  with colors as [‘r’, ‘y’, ‘g’,’b’] and legend as “list of bikes details” and title as “pie plot” and take a screen shot of the graph.

# %%
days = [1, 2, 3, 4, 5]
labels=['Day1','Day2','Day3','Day4','Day5']
Enfield = [50, 40, 70, 80, 20]
Honda = [80,20,20,50,60]
Yahama = [70,20,60,40,60]
KTM = [80,20,20,50,60]
color=['r', 'y', 'g','b']
fig=plt.figure('Pie plot')
plt1=fig.add_subplot(221)
plt2=fig.add_subplot(222)
plt3=fig.add_subplot(223)
plt4=fig.add_subplot(224)


plt1.pie(Enfield,labels=labels)
plt1.set_title('Enfield')
#plt1.legend(loc=10)
plt2.pie(Honda,labels=labels)
plt2.set_title('Honda')
#plt2.legend()
plt3.pie(Yahama,labels=labels)
plt3.set_title('Yahama')
#plt3.legend()
plt4.pie(KTM,labels=labels)
plt4.set_title('KTM')
#plt4.legend()
fig.legend(('Day1','Day2','Day3','Day4','Day5'))

# %% [markdown]
# 5.	Use the same tabular data and create a scatter plot days as x values [1,2,3,4,5] and bike details as y1,y2,y3,y4,y5 namely label as ‘Enfield’,’Honda’,’Yahama’ and ‘KTM’ and x, y labels as ‘days’ and ‘distance’ and take a screen shot of the graph.

# %%
days = [1, 2, 3, 4, 5]
y1 = [50, 40, 70, 80, 20] 
y2 = [80,20,20,50,60] 
y3 = [70,20,60,40,60] 
y4 = [80,20,20,50,60]
plt.scatter(days,y1,color='r',label='Enfield')
plt.scatter(days,y2,color='y',label='Honda')
plt.scatter(days,y3,color='g',label='Yamaha')
plt.scatter(days,y4,color='b',label='KTM')
plt.legend()
plt.xlabel('days')
plt.ylabel('distance')
plt.title('Days and distance')
plt.show()

# %% [markdown]
# 6.	Plot a histogram
# days =[50 ,80,70,80,40,20,20,20,70,20,60,20,80,50,40,50,20,60,60,60]
# bins = [0,10,20,40,50,60,70,80,90,100]
# Print the x, y labels as “distance” and “km count” and take a screen shot of the graph.

# %%
days =[50 ,80,70,80,40,20,20,20,70,20,60,20,80,50,40,50,20,60,60,60] 
bins = [0,10,20,40,50,60,70,80,90,100]
rang=(0,100)
bins=10
plt.hist(days,bins,rang,histtype='bar',rwidth=0.8)
plt.xlabel('distance')
plt.ylabel('km count')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')
